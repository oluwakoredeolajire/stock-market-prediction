# %%
import os
import sys
import pandas as pd
import import_ipynb
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

sys.path.append(os.path.abspath(".."))

from src.model import train_linear_regression, train_random_forest
from src.utils import plot_predictions
from src.config import PROCESSED_DATA_PATH
import notebooks.data_preprocessing as dp

# %%
# Load processed data
processed_data = pd.read_csv(os.path.join(PROCESSED_DATA_PATH, 'processed_data.csv'))

# %%
# Split features and target
X_train_scaled = processed_data.iloc[:len(X_train), :-1]
